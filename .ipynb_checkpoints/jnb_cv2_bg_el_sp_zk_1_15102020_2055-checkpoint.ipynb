# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
imge1 = cv2.imread('E:/KrishM/ML/IMG/elon/9k_ (2).jpg')

# %%
imge1.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(imge1)

# %%
imge2 = cv2.imread('E:/KrishM/ML/IMG/elon/images (3).jpg')

# %%
imge2.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(imge2)

# %%
gray2 = cv2.cvtColor(imge2, cv2.COLOR_BGR2GRAY)

# %%
gray2.shape
# Out:
# (225, 225)

# %%
plt.imshow(gray2)

# %%
gray2.shape
# Out:
# (225, 225)

# %%
gray2
# Out:
# array([[ 3,  3,  3, ...,  2,  2,  2],
#        [ 3,  3,  3, ...,  2,  2,  2],
#        [ 3,  3,  3, ...,  2,  2,  2],
#        ...,
#        [12, 11, 10, ..., 12, 20, 21],
#        [12, 11, 10, ..., 12, 22, 21],
#        [14, 10,  7, ..., 17, 18, 18]], dtype=uint8)

# %%
imge3 = cv2.imread('E:/KrishM/ML/IMG/sun/2Q__ (2).jpg')

# %%
imge3.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(imge3)

# %%
imge5 = cv2.imread('E:/KrishM/ML/IMG/zuc/2Q__.jpg')

# %%
imge5.shape
# Out:
# (100, 100, 3)

# %%
type(imge5)
# Out:
# numpy.ndarray

# %%
plt.imshow(imge5)

# %%
imge4 = cv2.imread('E:/KrishM/ML/IMG/bill/bill26.jpg')

# %%
type(imge4)
# Out:
# numpy.ndarray

# %%
imge4.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(imge4)

# %%
imgb2 = cv2.imread('E:/KrishM/ML/IMG/bill/bill45.jpg')

# %%
type(imgb2)
# Out:
# numpy.ndarray

# %%
imgb2.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(imgb2)

# %%
graybw1
# Out:
# array([[111, 167, 146, ...,   9,   9,   9],
#        [118, 130, 113, ...,   9,   9,   9],
#        [105, 131, 111, ...,  10,  10,  10],
#        ...,
#        [170, 179, 179, ..., 173, 172, 172],
#        [168, 185, 170, ..., 172, 172, 172],
#        [162, 185, 184, ..., 172, 172, 171]], dtype=uint8)

# %%
plt.imshow(graybw1)
