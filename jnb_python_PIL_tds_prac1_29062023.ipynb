# %%
from PIL import Image
import os

# %%
img1 = Image.open('E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/cat.912.jpg')

# %%
img2 = Image.open('E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/cat.902.jpg')

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x330>

# %%
img3 = img2.save('E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/cat_902.png')

# %%
img3 = Image.open('E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/cat_902.png')

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x330>

# %%
files = os.listdir('E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset')

# %%
files
# Out:
# ['cat.1308.jpg',
#  'cat.1309.jpg',
#  'cat.1310.jpg',
#  'cat.1311.jpg',
#  'cat.1312.jpg',
#  'cat.1313.jpg',
#  'cat.1315.jpg',
#  'cat.1316.jpg',
#  'cat.1318.jpg',
#  'cat.1319.jpg',
#  'cat.1320.jpg',
#  'cat.1321.jpg',
#  'cat.1322.jpg',
#  'cat.1323.jpg',
#  'cat.1324.jpg',
#  'cat.1325.jpg',
#  'cat.1326.jpg',
#  'cat.1327.jpg',
#  'cat.1328.jpg',
#  'cat.1329.jpg',
#  'cat.877.jpg',
#  'cat.878.jpg',
#  'cat.879.jpg',
#  'cat.880.jpg',
#  'cat.881.jpg',
#  'cat.882.jpg',
#  'cat.883.jpg',
#  'cat.884.jpg',
#  'cat.885.jpg',
#  'cat.886.jpg',
#  'cat.887.jpg',
#  'cat.888.jpg',
#  'cat.889.jpg',
#  'cat.890.jpg',
#  'cat.891.jpg',
#  'cat.892.jpg',
#  'cat.893.jpg',
#  'cat.894.jpg',
#  'cat.895.jpg',
#  'cat.896.jpg',
#  'cat.897.jpg',
#  'cat.898.jpg',
#  'cat.899.jpg',
#  'cat.900.jpg',
#  'cat.901.jpg',
#  'cat.902.jpg',
#  'cat.903.jpg',
#  'cat.904.jpg',
#  'cat.905.jpg',
#  'cat.906.jpg',
#  'cat.907.jpg',
#  'cat.908.jpg',
#  'cat.909.jpg',
#  'cat.910.jpg',
# ...

# %%
pngf = []
for f in files:
    if f.endswith('.png'):
        pngf.append(f)

# %%
pngf
# Out:
# ['cat.912.png', 'cat_902.png']

# %%
cat13s = []
for f in files:
    if 'cat.13' in f:
        cat13s.append(f)
print(cat13s)
# Out:
# ['cat.1308.jpg', 'cat.1309.jpg', 'cat.1310.jpg', 'cat.1311.jpg', 'cat.1312.jpg', 'cat.1313.jpg', 'cat.1315.jpg', 'cat.1316.jpg', 'cat.1318.jpg', 'cat.1319.jpg', 'cat.1320.jpg', 'cat.1321.jpg', 'cat.1322.jpg', 'cat.1323.jpg', 'cat.1324.jpg', 'cat.1325.jpg', 'cat.1326.jpg', 'cat.1327.jpg', 'cat.1328.jpg', 'cat.1329.jpg']

# %%
for f in os.listdir('E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset'):
    if f.endswith('.jpg'):
        i = Image.open(f'E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/{f}')
        fn, fext = os.path.splitext(f'E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/{f}')
        print(fn, ' ', fext)
        path = fn[:50]
#         print(path)
        i.save(f'{path}PNGs/{fn.split('/')[-1]}.png')
# Out:
#   File "<ipython-input-73-a6e393ff4d3a>", line 8
#     i.save(f'{path}PNGs/{fn.split('/')[-1]}.png')
#            ^
# SyntaxError: f-string: unmatched '('

# %%
str1 = 'jkanc/wdm'

# %%
str1.strip('/dwm')
# Out:
# 'jkanc'

# %%
p = 'E:/KrishM/PythonPrjs/PyDatasets/ctdgex/testingset/cat.1308'

# %%
p.split('/')[-1]
# Out:
# 'cat.1308'

# %%
name = 'ter'

# %%
print(f'{name}.wanlas')
# Out:
# ter.wanlas
